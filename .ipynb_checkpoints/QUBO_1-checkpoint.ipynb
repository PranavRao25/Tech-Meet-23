# %%
import networkx as nx
import matplotlib as plt
import numpy as np
import time
from qiskit_optimization.applications import Tsp
from qiskit.visualization import array_to_latex
from qiskit.circuit.library import TwoLocal
from qiskit_algorithms.minimum_eigensolvers import SamplingVQE,VQE,SamplingMinimumEigensolver
from qiskit_optimization.algorithms import MinimumEigenOptimizer
from qiskit_algorithms.optimizers import SPSA
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, random_statevector
from qiskit.quantum_info.operators import Operator, Pauli
from qiskit.primitives import Sampler,Estimator

# %% [markdown]
# <h1>Basic WorkFlow</h1>
# <ol>
# 1. Construct the Graph<br>
# 2. Construct the $Q$ matrix from the weight matrix.<br>
# 3. We will be converting it into a MaxCut problem. Use the <code>Maxcut</code> function from <code>qiskit_optimization.applications</code> library to create a quadratic program. <br>
# 4. Map the quadratic program as Ising problem; N qubits for N variables <br>
# 5. Solving using VQE :<br>
#     a. Generate an ansatz circuit (choose the entangled strategy as <i>linear</i> (it depends))<br>
#     b. Select an optimizer<br>
#     c. Run the VQE Algorithm as:<br>
#         <code>vqe = SamplingVQE(sampler=Sampler(),ansatz,optimiser)</code><br>
#         <code>vqe_1 = MinimumEigenOptimizer(vqe)</code><br>
#     d. Get the result as <code>vqe_1.solve(quadratic program)</code><br>

# %% [markdown]
# How VQE works:<br>
# Finds the minimum eigenvalue of a Hamiltonian<br>
# QUBO problems are turned into Ising problems which are solved using VQE<br>
# It is a hybrid algorithm (classical & quantum)
#     1. Fix a guess of parameters. (Classical)<br>
#     2. Generate a parameterised circuit (which represents a wave function/quantum state) (Quantum)<br>
#     3. Find its Minimum Eigenvalue (Quantum)<br>
#     4. Change the parameter and repeat till minimum found.(Classical)<br>

# %%
G = nx.Graph()
G.add_nodes_from(range(5))

# 0 1 2 3 4
edges = [
    (0,1,10),
    (1,2,34),
    (2,4,50),
    (3,0,12),
    (4,1,45),
    (2,3,13),
    (3,1,56),
]
# edges = [(0,3,1),(1,2,1),(3,4,2),(2,3,2),(1,3,3),(0,4,2),(2,4,1)]
G.add_weighted_edges_from(edges)
nx.draw(G)

# %%
wMat = np.zeros([5,5])

# %%
for i in edges:
    wMat[i[0],i[1]] = i[2]

# %%
array_to_latex(wMat)
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 10 & 0 & 0 & 0  \\
#  0 & 0 & 34 & 0 & 0  \\
#  0 & 0 & 0 & 13 & 50  \\
#  12 & 56 & 0 & 0 & 0  \\
#  0 & 45 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %%
tsp = Tsp(wMat)

# %%
max_cut.draw()

# %%
program = tsp.to_quadratic_program()
print(program.prettyprint())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 program = tsp.to_quadratic_program()
#       2 print(program.prettyprint())
#
# File ~/.local/lib/python3.8/site-packages/qiskit_optimization/applications/tsp.py:49, in Tsp.to_quadratic_program(self)
#      47 n = self._graph.number_of_nodes()
#      48 x = {(i, k): mdl.binary_var(name=f"x_{i}_{k}") for i in range(n) for k in range(n)}
# ---> 49 tsp_func = mdl.sum(
#      50     self._graph.edges[i, j]["weight"] * x[(i, k)] * x[(j, (k + 1) % n)]
#      51     for i in range(n)
#      52     for j in range(n)
#      53     for k in range(n)
#      54     if i != j
#      55 )
#      56 mdl.minimize(tsp_func)
#      57 for i in range(n):
#
# File ~/.local/lib/python3.8/site-packages/docplex/mp/model.py:3274, in Model.sum(self, args)
#    3261 def sum(self, args):
#    3262     """ Creates an expression summing over an iterable over expressions or variables.
#    3263     This method expects an iterable over any type of expression: quadrayic expression,
#    3264     linear expression, variables, constants.
#    (...)
#    3272     :return: A Docplex expression.
#    3273     """
# -> 3274     return self._aggregator.sum(args)
#
# File ~/.local/lib/python3.8/site-packages/docplex/mp/aggregator.py:198, in ModelAggregator.sum(self, sum_args)
#     196 def sum(self, sum_args):
#     197     if is_iterator(sum_args):
# --> 198         sum_res = self._sum_with_iter(sum_args)
#     199     elif is_numpy_ndarray(sum_args):
#     200         sum_res = self._sum_with_iter(sum_args.flat)
#
# File ~/.local/lib/python3.8/site-packages/docplex/mp/aggregator.py:221, in ModelAggregator._sum_with_iter(self, args)
#     219 qcc = None
#     220 number_validation_fn = checker.get_number_validation_fn()
# --> 221 for item in args:
#     222     if isinstance(item, LinearOperand):
#     223         for lv, lk in item.iter_terms():
#
# File ~/.local/lib/python3.8/site-packages/qiskit_optimization/applications/tsp.py:50, in <genexpr>(.0)
#      47 n = self._graph.number_of_nodes()
#      48 x = {(i, k): mdl.binary_var(name=f"x_{i}_{k}") for i in range(n) for k in range(n)}
#      49 tsp_func = mdl.sum(
# ---> 50     self._graph.edges[i, j]["weight"] * x[(i, k)] * x[(j, (k + 1) % n)]
#      51     for i in range(n)
#      52     for j in range(n)
#      53     for k in range(n)
#      54     if i != j
#      55 )
#      56 mdl.minimize(tsp_func)
#      57 for i in range(n):
#
# File ~/.local/lib/python3.8/site-packages/networkx/classes/reportviews.py:1085, in OutEdgeView.__getitem__(self, e)
#    1080     raise nx.NetworkXError(
#    1081         f"{type(self).__name__} does not support slicing, "
#    1082         f"try list(G.edges)[{e.start}:{e.stop}:{e.step}]"
#    1083     )
#    1084 u, v = e
# -> 1085 return self._adjdict[u][v]
#
# KeyError: 2

# %%
qubitOp,offset = program.to_ising()

# %%
array_to_latex(qubitOp.to_matrix())
# Out:
# $$
#
# \begin{bmatrix}
# 4 & 0 & 0 & 0 & \cdots & 0 & 0 & 0  \\
#  0 & 3 & 0 & 0 & \cdots & 0 & 0 & 0  \\
#  0 & 0 & 3 & 0 & \cdots & 0 & 0 & 0  \\
#  0 & 0 & 0 & 2 & \cdots & 0 & 0 & 0  \\
#  \vdots & \vdots & \vdots & \vdots & \ddots & \vdots & \vdots & \vdots \\
#  0 & 0 & 0 & 0 & \cdots & 3 & 0 & 0  \\
#  0 & 0 & 0 & 0 & \cdots & 0 & 3 & 0  \\
#  0 & 0 & 0 & 0 & \cdots & 0 & 0 & 4  \\
#  \end{bmatrix}
# $$

# %%
two = TwoLocal(3,'rx','cx','linear',reps=2,insert_barriers=True)

# %%
(two.decompose()).draw()
# Out:
#      ┌──────────┐ ░            ░ ┌──────────┐ ░            ░ ┌──────────┐
# q_0: ┤ Rx(θ[0]) ├─░───■────────░─┤ Rx(θ[3]) ├─░───■────────░─┤ Rx(θ[6]) ├
#      ├──────────┤ ░ ┌─┴─┐      ░ ├──────────┤ ░ ┌─┴─┐      ░ ├──────────┤
# q_1: ┤ Rx(θ[1]) ├─░─┤ X ├──■───░─┤ Rx(θ[4]) ├─░─┤ X ├──■───░─┤ Rx(θ[7]) ├
#      ├──────────┤ ░ └───┘┌─┴─┐ ░ ├──────────┤ ░ └───┘┌─┴─┐ ░ ├──────────┤
# q_2: ┤ Rx(θ[2]) ├─░──────┤ X ├─░─┤ Rx(θ[5]) ├─░──────┤ X ├─░─┤ Rx(θ[8]) ├
#      └──────────┘ ░      └───┘ ░ └──────────┘ ░      └───┘ ░ └──────────┘

# %%
t1 = time.ctime().split()[3] # 35 s
two = TwoLocal(5,'rx','cx','linear',reps=2,insert_barriers=True)
optimizer = SPSA(maxiter=3000)
vqe = SamplingVQE(sampler=Sampler(),ansatz=two,optimizer=optimizer)
vqe_op1 = MinimumEigenOptimizer(vqe)
result = vqe_op1.solve(program)
t2 = time.ctime().split()[3]
print(t2,t1)
print(result.prettyprint())
# Out:
# 11:37:34 11:36:59
# objective function value: 8.0
# variable values: x_0=0.0, x_1=1.0, x_2=0.0, x_3=1.0, x_4=0.0
# status: SUCCESS

# %%
t1 = time.ctime().split()[3] # 43 s
two = TwoLocal(5,'rx','cx','full',reps=2,insert_barriers=True)
optimizer = SPSA(maxiter=3000)
vqe = SamplingVQE(sampler=Sampler(),ansatz=two,optimizer=optimizer)
vqe_op1 = MinimumEigenOptimizer(vqe)
result = vqe_op1.solve(program)
t2 = time.ctime().split()[3]
print(t2,t1)
print(result.prettyprint())
# Out:
# 17:44:27 17:43:44
# objective function value: 4.0
# variable values: x_0=0.0, x_1=1.0, x_2=0.0, x_3=1.0, x_4=0.0
# status: SUCCESS

# %%
t1 = time.ctime().split()[3] # 36 s
two = TwoLocal(5,'rx','cx','reverse_linear',reps=2,insert_barriers=True)
optimizer = SPSA(maxiter=3000)
vqe = SamplingVQE(sampler=Sampler(),ansatz=two,optimizer=optimizer)
vqe_op1 = MinimumEigenOptimizer(vqe)
result = vqe_op1.solve(program)
t2 = time.ctime().split()[3]
print(t2,t1)
print(result.prettyprint())
# Out:
# 17:45:17 17:44:41
# objective function value: 4.0
# variable values: x_0=0.0, x_1=1.0, x_2=0.0, x_3=1.0, x_4=0.0
# status: SUCCESS

# %%
t1 = time.ctime().split()[3] # 34 s
two = TwoLocal(5,'rx','cx','pairwise',reps=2,insert_barriers=True)
optimizer = SPSA(maxiter=3000)
vqe = SamplingVQE(sampler=Sampler(),ansatz=two,optimizer=optimizer)
vqe_op1 = MinimumEigenOptimizer(vqe)
result = vqe_op1.solve(program)
t2 = time.ctime().split()[3]
print(t2,t1)
print(result.prettyprint())
# Out:
# 17:45:51 17:45:17
# objective function value: 4.0
# variable values: x_0=1.0, x_1=0.0, x_2=1.0, x_3=0.0, x_4=1.0
# status: SUCCESS

# %%
t1 = time.ctime().split()[3] # 36 s
two = TwoLocal(5,'rx','cx','circular',reps=2,insert_barriers=True)
optimizer = SPSA(maxiter=3000)
vqe = SamplingVQE(sampler=Sampler(),ansatz=two,optimizer=optimizer)
vqe_op1 = MinimumEigenOptimizer(vqe)
result = vqe_op1.solve(program)
t2 = time.ctime().split()[3]
print(t2,t1)
print(result.prettyprint())
# Out:
# 17:46:27 17:45:51
# objective function value: 4.0
# variable values: x_0=0.0, x_1=1.0, x_2=0.0, x_3=1.0, x_4=0.0
# status: SUCCESS

# %%
t1 = time.ctime().split()[3] # 38 s
two = TwoLocal(5,'rx','cx','sca',reps=2,insert_barriers=True)
optimizer = SPSA(maxiter=3000)
vqe = SamplingVQE(sampler=Sampler(),ansatz=two,optimizer=optimizer)
vqe_op1 = MinimumEigenOptimizer(vqe)
result = vqe_op1.solve(program)
t2 = time.ctime().split()[3]
print(t2,t1)
print(result.prettyprint())
# Out:
# 17:47:05 17:46:27
# objective function value: 4.0
# variable values: x_0=0.0, x_1=1.0, x_2=0.0, x_3=1.0, x_4=0.0
# status: SUCCESS

# %%
colors = ["g" if result.x[i] == 0 else "r" for i in range(5)]
nx.draw(G, node_color=colors)
